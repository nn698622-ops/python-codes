# %%
a=10

# %%
a=a+10

# %%
a=a**2

# %%
a=a/2

# %%
a="200"

# %%
f=open("sample.txt","w")

# %%
f.write(a)
# Out:
# 3

# %%
f.close()

# %%
f=open("sample.txt","r")
d=f.read()
a=1/0
f.close()

# %%
d=f.read()

# %%
f.close()

# %%
with open("sample.txt","w") as f:
    a=int(input("enter a number")) 
    b=int(input("enter a next number"))
    c=a+b
    f.write(str(c))

# %%
a=input()

# %%
str(8)
# Out:
# '8'

# %%
type(a)
# Out:
# str
