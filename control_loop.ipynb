# %%
w=10
w>5
# Out:
# True

# %%
if w>15:
    print("hi")
    print("hello")
else:
    print("hello")
print("name")
# Out:
# hello
# name

# %%
print("hi") if w>5 else print("helo")
# Out:
# hi

# %%
w
# Out:
# 10

# %%
mark=80

# %%
if mark>90:
    print("a")
elif mark>80:
    print("b")
else:
    print("failed")
# Out:
# failed

# %%
t=(5,6,7,8)

# %%
t[0]
# Out:
# 5

# %%
for i in t:
    print(i)
# Out:
# 5
# 6
# 7
# 8

# %%
l=[2,3,4,5,6,7]
for i in l:
    if i%2==0:
        print("even")
    else:
        print("odd")
# Out:
# even
# odd
# even
# odd
# even
# odd

# %%
b="hello"
b[0]
# Out:
# 'h'

# %%
s={1,3,4}
for i in s:
    print(i)
# Out:
# 1
# 3
# 4

# %%
type(s)
# Out:
# set

# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9
