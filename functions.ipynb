# %%
def demo(a,b):
    c=a+b
   
    print(j)

# %%
demo(4,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 demo(4,7)
#
# Cell In[24], line 4, in demo(a, b)
#       1 def demo(a,b):
#       2     c=a+b
#       3
# ----> 4     print(j)
#
# NameError: name 'j' is not defined

# %%
def demo(a,b):
    c=a+b
   
    print(b)

# %%
a=3
b=2

demo(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 a=3
#       2 b=2
#       3
# ----> 4 demo(b)
#
# TypeError: demo() missing 1 required positional argument: 'b'

# %%
def demo(a,b=0):
    c=a+b
    print(b)

demo(2,6)
# Out:
# 6

# %%
demo(2)
# Out:
# 0
